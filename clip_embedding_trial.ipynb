# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\asus\anaconda3\lib\site-packages (4.56.0)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\asus\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asus\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests->transformers) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\asus\anaconda3\lib\site-packages)

# %%
from transformers import CLIPProcessor, CLIPModel
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# c:\Users\ASUS\anaconda3\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ASUS\.cache\huggingface\hub\models--openai--clip-vit-base-patch32. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from transformers import CLIPProcessor, CLIPModel
# ----> 2 clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
#       3 clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\transformers\modeling_utils.py:288, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     286 old_dtype = torch.get_default_dtype()
#     287 try:
# --> 288     return func(*args, **kwargs)
#     289 finally:
#     290     torch.set_default_dtype(old_dtype)
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\transformers\modeling_utils.py:5176, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    5166     if dtype_orig is not None:
#    5167         torch.set_default_dtype(dtype_orig)
#    5169     (
#    5170         model,
#    5171         missing_keys,
#    5172         unexpected_keys,
#    5173         mismatched_keys,
#    5174         offload_index,
#    5175         error_msgs,
# -> 5176     ) = cls._load_pretrained_model(
#    5177         model,
#    5178         state_dict,
#    5179         checkpoint_files,
#    5180         pretrained_model_name_or_path,
#    5181         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    5182         sharded_metadata=sharded_metadata,
#    5183         device_map=device_map,
#    5184         disk_offload_folder=offload_folder,
#    5185         offload_state_dict=offload_state_dict,
#    5186         dtype=dtype,
#    5187         hf_quantizer=hf_quantizer,
#    5188         keep_in_fp32_regex=keep_in_fp32_regex,
#    5189         device_mesh=device_mesh,
#    5190         key_mapping=key_mapping,
#    5191         weights_only=weights_only,
#    5192     )
#    5193 # make sure token embedding weights are still tied if needed
#    5194 model.tie_weights()
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\transformers\modeling_utils.py:5442, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, checkpoint_files, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, device_map, disk_offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_regex, device_mesh, key_mapping, weights_only)
#    5439     original_checkpoint_keys = list(state_dict.keys())
#    5440 else:
#    5441     original_checkpoint_keys = list(
# -> 5442         load_state_dict(checkpoint_files[0], map_location="meta", weights_only=weights_only).keys()
#    5443     )
#    5445 # Check if we are in a special state, i.e. loading from a state dict coming from a different architecture
#    5446 prefix = model.base_model_prefix
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\transformers\modeling_utils.py:532, in load_state_dict(checkpoint_file, is_quantized, map_location, weights_only)
#     530 # Fallback to torch.load (if weights_only was explicitly False, do not check safety as this is known to be unsafe)
#     531 if weights_only:
# --> 532     check_torch_load_is_safe()
#     533 try:
#     534     if map_location is None:
#
# File c:\Users\ASUS\anaconda3\lib\site-packages\transformers\utils\import_utils.py:1632, in check_torch_load_is_safe()
#    1630 def check_torch_load_is_safe() -> None:
#    1631     if not is_torch_greater_or_equal("2.6"):
# -> 1632         raise ValueError(
#    1633             "Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users "
#    1634             "to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply "
#    1635             "when loading files with safetensors."
#    1636             "\nSee the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434"
#    1637         )
#
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
